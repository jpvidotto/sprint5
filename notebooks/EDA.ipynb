# %%
import pandas as pd
import plotly.express as px

car_data = pd.read_csv('c:/Users/jpvid/OneDrive/Documents/GitHub/sprint5/dataframe/vehicles.csv')
fig = px.scatter(car_data, x="odometer", y="price")
fig.show()
